# %%
from experimental_modeling_pipeline import Experimental_modeling_pipeline as emp
from experimental_modeling_pipeline import Data_engineering as de
from experimental_modeling_pipeline import DiabetesPreprocessing as dp
import pandas as pd

emp = emp()
dp = dp("C:/Users/keimp/")

# %%
labels = dp.pre_first_occurence_labels()
# Out:
# C:\Users\keimp\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3318: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if await self.run_code(code, result, async_=asy):
# C:\Users\keimp\NHS\Code\experimental_modeling\diabetes\experimental_modeling_pipeline.py:716: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   return pd.np.nan
# Varible not convertable to datetime:  Date E11 first reported (non-insulin-dependent diabetes mellitus)    Code has event date matching participant's dat...
# Date E14 first reported (unspecified diabetes mellitus)                                                     1998-11-01
# Name: 225392, dtype: object
# Varible not convertable to datetime:  Date E10 first reported (insulin-dependent diabetes mellitus)                                               2007-05-10
# ...

# %% [markdown]
# ### Family history(diabetes)

# %%
df = dp.pre_family_history().merge(labels, on="Participant ID")
df2 = df.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, splits=5)
# Out:
# Number of missing values:
#  Participant ID              0
# Illnesses of father         0
# Illnesses of mother         0
# Illnesses of siblings       0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 6)
# F1:  0.4971842702902484 0.4971842702902484 0.4971842702902484
# auc:  [0.5, 0.6054000509069545, 0.6054000509069545, 0.6054000509069545]
# accuracy:  [0.5, 0.5967622751579971, 0.5967622751579971, 0.5967622751579971]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID              0
# Illnesses of father         0
# Illnesses of mother         0
# Illnesses of siblings       0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 6)
# F1_macro:  0.3362866808724458 0.3606804820928326 0.3362866808724458
# F1_micro:  0.5279436071949442 0.5140495867768595 0.5279436071949442
# auc:  [0.5, 0.5816528954864151, 0.5789551962333986, 0.581609050725664]
# accuracy:  [0.5, 0.5279436071949442, 0.5140495867768595, 0.5279436071949442]

# %% [markdown]
# ### Demographics(ethnicity)

# %%
df = dp.pre_demographics_ethnicity().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, splits=5)
# Out:
# Number of missing values:
#  Participant ID              0
# Asian                       0
# Black                       0
# Chinese                     0
# Mixed                       0
# Other                       0
# White                       0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 9)
# F1:  0.2125962883288511 0.2125962883288511 0.2125962883288511
# auc:  [0.5, 0.5371326613016629, 0.536681384621893, 0.5371304870027739]
# accuracy:  [0.5, 0.5364705882352941, 0.5364705882352941, 0.5364705882352941]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID              0
# Asian                       0
# Black                       0
# Chinese                     0
# Mixed                       0
# Other                       0
# White                       0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 9)
# F1_macro:  0.2851484794110867 0.2970141796387234 0.2851484794110867
# F1_micro:  0.5100437530384054 0.5075255226057365 0.5100437530384054
# auc:  [0.5, 0.5288491270130542, 0.5215743394970928, 0.5288484312374098]
# accuracy:  [0.5, 0.5100437530384054, 0.5075255226057365, 0.5100437530384054]

# %% [markdown]
# ### Bodymeasures

# %%
df = dp.pre_bodymeasures().merge(labels, on="Participant ID")
df2 = df.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, splits=5)
# Out:
# Number of missing values:
#  Participant ID                               0
# fmi                                       3038
# Body mass index (BMI) | Instance 0         925
# Body fat percentage | Instance 0          2867
# Waist circumference | Instance 0           597
# Weight | Instance 0                        806
# Hip circumference | Instance 0             617
# Whole body fat mass | Instance 0          2950
# Basal metabolic rate | Instance 0         2820
# Trunk fat percentage | Instance 0         2881
# Arm fat percentage (left) | Instance 0    2852
# Leg fat percentage (left) | Instance 0    2829
# first_occurence_binary                       0
# first_occurence_tertiary                     0
# dtype: int64
# Dataframe dimensions:  (99701, 14)
# F1:  0.7019822976367928 0.6079541336101514 0.69647057944552
# auc:  [0.5046589302013019, 0.7775893322171394, 0.7213068646621595, 0.7636913301634998]
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Participant ID                            0
# fmi                                       0
# Body mass index (BMI) | Instance 0        0
# Body fat percentage | Instance 0          0
# Waist circumference | Instance 0          0
# Weight | Instance 0                       0
# Hip circumference | Instance 0            0
# Whole body fat mass | Instance 0          0
# Basal metabolic rate | Instance 0         0
# Trunk fat percentage | Instance 0         0
# Arm fat percentage (left) | Instance 0    0
# Leg fat percentage (left) | Instance 0    0
# first_occurence_binary                    0
# first_occurence_tertiary                  0
# dtype: int64
# Dataframe dimensions:  (102850, 14)
# F1_macro:  0.7082615663132388 0.649045614848106 0.6992006828427411
# F1_micro:  0.7082839086047642 0.6538065143412737 0.699212445308702
# auc:  [0.5, 0.7762221036861692, 0.7211083564214726, 0.7634377177991651]
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Participant ID                            0
# fmi                                       0
# Body mass index (BMI) | Instance 0        0
# Body fat percentage | Instance 0          0
# Waist circumference | Instance 0          0
# Weight | Instance 0                       0
# Hip circumference | Instance 0            0
# Whole body fat mass | Instance 0          0
# Basal metabolic rate | Instance 0         0
# Trunk fat percentage | Instance 0         0
# Arm fat percentage (left) | Instance 0    0
# Leg fat percentage (left) | Instance 0    0
# first_occurence_binary                    0
# first_occurence_tertiary                  0
# dtype: int64
# Dataframe dimensions:  (102850, 14)
# F1_macro:  0.7080302555667489 0.6486062881938002 0.6995897932499968
# F1_micro:  0.7080505590666019 0.6534370442391833 0.6996013612056393
# auc:  [0.5, 0.775995078521732, 0.7206939170916199, 0.7638864193527727]
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Participant ID                            0
# fmi                                       0
# Body mass index (BMI) | Instance 0        0
# Body fat percentage | Instance 0          0
# Waist circumference | Instance 0          0
# Weight | Instance 0                       0
# Hip circumference | Instance 0            0
# Whole body fat mass | Instance 0          0
# Basal metabolic rate | Instance 0         0
# Trunk fat percentage | Instance 0         0
# Arm fat percentage (left) | Instance 0    0
# Leg fat percentage (left) | Instance 0    0
# first_occurence_binary                    0
# first_occurence_tertiary                  0
# dtype: int64
# Dataframe dimensions:  (102850, 14)
# F1_macro:  0.7111306700714777 0.6550212737828265 0.7084066975176984
# F1_micro:  0.7111618862421002 0.6592805055906661 0.7084103062712689
# auc:  [0.5, 0.7789910960097125, 0.7246223826581701, 0.7776884432941668]
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                               0
# fmi                                       3038
# Body mass index (BMI) | Instance 0         925
# Body fat percentage | Instance 0          2867
# Waist circumference | Instance 0           597
# Weight | Instance 0                        806
# Hip circumference | Instance 0             617
# Whole body fat mass | Instance 0          2950
# Basal metabolic rate | Instance 0         2820
# Trunk fat percentage | Instance 0         2881
# Arm fat percentage (left) | Instance 0    2852
# Leg fat percentage (left) | Instance 0    2829
# first_occurence_binary                       0
# first_occurence_tertiary                     0
# dtype: int64
# Dataframe dimensions:  (99701, 14)
# F1_macro:  0.4474747372222132 0.4394373114654831 0.4637134135020233
# F1_micro:  0.5694726770955261 0.532171161697318 0.5582792336691133
# auc:  [0.5046589302013019, 0.720794955606646, 0.6717997929849844, 0.7012217411600351]
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Participant ID                            0
# fmi                                       0
# Body mass index (BMI) | Instance 0        0
# Body fat percentage | Instance 0          0
# Waist circumference | Instance 0          0
# Weight | Instance 0                       0
# Hip circumference | Instance 0            0
# Whole body fat mass | Instance 0          0
# Basal metabolic rate | Instance 0         0
# Trunk fat percentage | Instance 0         0
# Arm fat percentage (left) | Instance 0    0
# Leg fat percentage (left) | Instance 0    0
# first_occurence_binary                    0
# first_occurence_tertiary                  0
# dtype: int64
# Dataframe dimensions:  (102850, 14)
# F1_macro:  0.4471090571809822 0.4390679284910423 0.46182528554754226
# F1_micro:  0.566164316966456 0.5297131745260087 0.5522897423432183
# auc:  [0.5, 0.7188631182152224, 0.6711484305628791, 0.6988215583263304]
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Participant ID                            0
# fmi                                       0
# Body mass index (BMI) | Instance 0        0
# Body fat percentage | Instance 0          0
# Waist circumference | Instance 0          0
# Weight | Instance 0                       0
# Hip circumference | Instance 0            0
# Whole body fat mass | Instance 0          0
# Basal metabolic rate | Instance 0         0
# Trunk fat percentage | Instance 0         0
# Arm fat percentage (left) | Instance 0    0
# Leg fat percentage (left) | Instance 0    0
# first_occurence_binary                    0
# first_occurence_tertiary                  0
# dtype: int64
# Dataframe dimensions:  (102850, 14)
# F1_macro:  0.44698045076459514 0.4387828359951269 0.4633962504124784
# F1_micro:  0.5664268351968886 0.5295964997569276 0.553407875546913
# auc:  [0.5, 0.7189371458689013, 0.670860567628882, 0.6992665159242697]
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Participant ID                            0
# fmi                                       0
# Body mass index (BMI) | Instance 0        0
# Body fat percentage | Instance 0          0
# Waist circumference | Instance 0          0
# Weight | Instance 0                       0
# Hip circumference | Instance 0            0
# Whole body fat mass | Instance 0          0
# Basal metabolic rate | Instance 0         0
# Trunk fat percentage | Instance 0         0
# Arm fat percentage (left) | Instance 0    0
# Leg fat percentage (left) | Instance 0    0
# first_occurence_binary                    0
# first_occurence_tertiary                  0
# dtype: int64
# Dataframe dimensions:  (102850, 14)
# F1_macro:  0.4508314795545519 0.4434452568956141 0.48457400481609597
# F1_micro:  0.5678658240155566 0.532620320855615 0.5704910063198834
# auc:  [0.5, 0.7216691071358874, 0.6741991031570697, 0.7196230881040071]
# ...

# %% [markdown]
# ### Blood-biomarkers

# %%
df = dp.pre_blood_biomarker().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                                   0
# Haemoglobin concentration | Instance 0        5320
# Albumin | Instance 0                         15033
# Creatinine | Instance 0                       7115
# C-reactive protein | Instance 0               7308
# Cholesterol | Instance 0                      7074
# HDL cholesterol | Instance 0                 15098
# LDL direct | Instance 0                       7278
# Glucose | Instance 0                         15137
# Triglycerides | Instance 0                    7181
# Vitamin D | Instance 0                       11129
# Glycated haemoglobin (HbA1c) | Instance 0     7915
# Alanine aminotransferase | Instance 0         7136
# Alkaline phosphatase | Instance 0             7066
# Apolipoprotein A | Instance 0                15440
# Apolipoprotein B | Instance 0                 7781
# Aspartate aminotransferase | Instance 0       7469
# Calcium | Instance 0                         15063
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Participant ID                               0
# Haemoglobin concentration | Instance 0       0
# Albumin | Instance 0                         0
# Creatinine | Instance 0                      0
# C-reactive protein | Instance 0              0
# Cholesterol | Instance 0                     0
# HDL cholesterol | Instance 0                 0
# LDL direct | Instance 0                      0
# Glucose | Instance 0                         0
# Triglycerides | Instance 0                   0
# Vitamin D | Instance 0                       0
# Glycated haemoglobin (HbA1c) | Instance 0    0
# Alanine aminotransferase | Instance 0        0
# Alkaline phosphatase | Instance 0            0
# Apolipoprotein A | Instance 0                0
# Apolipoprotein B | Instance 0                0
# Aspartate aminotransferase | Instance 0      0
# Calcium | Instance 0                         0
# Direct bilirubin | Instance 0                0
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Participant ID                               0
# Haemoglobin concentration | Instance 0       0
# Albumin | Instance 0                         0
# Creatinine | Instance 0                      0
# C-reactive protein | Instance 0              0
# Cholesterol | Instance 0                     0
# HDL cholesterol | Instance 0                 0
# LDL direct | Instance 0                      0
# Glucose | Instance 0                         0
# Triglycerides | Instance 0                   0
# Vitamin D | Instance 0                       0
# Glycated haemoglobin (HbA1c) | Instance 0    0
# Alanine aminotransferase | Instance 0        0
# Alkaline phosphatase | Instance 0            0
# Apolipoprotein A | Instance 0                0
# Apolipoprotein B | Instance 0                0
# Aspartate aminotransferase | Instance 0      0
# Calcium | Instance 0                         0
# Direct bilirubin | Instance 0                0
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Participant ID                               0
# Haemoglobin concentration | Instance 0       0
# Albumin | Instance 0                         0
# Creatinine | Instance 0                      0
# C-reactive protein | Instance 0              0
# Cholesterol | Instance 0                     0
# HDL cholesterol | Instance 0                 0
# LDL direct | Instance 0                      0
# Glucose | Instance 0                         0
# Triglycerides | Instance 0                   0
# Vitamin D | Instance 0                       0
# Glycated haemoglobin (HbA1c) | Instance 0    0
# Alanine aminotransferase | Instance 0        0
# Alkaline phosphatase | Instance 0            0
# Apolipoprotein A | Instance 0                0
# Apolipoprotein B | Instance 0                0
# Aspartate aminotransferase | Instance 0      0
# Calcium | Instance 0                         0
# Direct bilirubin | Instance 0                0
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                                   0
# Haemoglobin concentration | Instance 0        5320
# Albumin | Instance 0                         15033
# Creatinine | Instance 0                       7115
# C-reactive protein | Instance 0               7308
# Cholesterol | Instance 0                      7074
# HDL cholesterol | Instance 0                 15098
# LDL direct | Instance 0                       7278
# Glucose | Instance 0                         15137
# Triglycerides | Instance 0                    7181
# Vitamin D | Instance 0                       11129
# Glycated haemoglobin (HbA1c) | Instance 0     7915
# Alanine aminotransferase | Instance 0         7136
# Alkaline phosphatase | Instance 0             7066
# Apolipoprotein A | Instance 0                15440
# Apolipoprotein B | Instance 0                 7781
# Aspartate aminotransferase | Instance 0       7469
# Calcium | Instance 0                         15063
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Participant ID                               0
# Haemoglobin concentration | Instance 0       0
# Albumin | Instance 0                         0
# Creatinine | Instance 0                      0
# C-reactive protein | Instance 0              0
# Cholesterol | Instance 0                     0
# HDL cholesterol | Instance 0                 0
# LDL direct | Instance 0                      0
# Glucose | Instance 0                         0
# Triglycerides | Instance 0                   0
# Vitamin D | Instance 0                       0
# Glycated haemoglobin (HbA1c) | Instance 0    0
# Alanine aminotransferase | Instance 0        0
# Alkaline phosphatase | Instance 0            0
# Apolipoprotein A | Instance 0                0
# Apolipoprotein B | Instance 0                0
# Aspartate aminotransferase | Instance 0      0
# Calcium | Instance 0                         0
# Direct bilirubin | Instance 0                0
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Participant ID                               0
# Haemoglobin concentration | Instance 0       0
# Albumin | Instance 0                         0
# Creatinine | Instance 0                      0
# C-reactive protein | Instance 0              0
# Cholesterol | Instance 0                     0
# HDL cholesterol | Instance 0                 0
# LDL direct | Instance 0                      0
# Glucose | Instance 0                         0
# Triglycerides | Instance 0                   0
# Vitamin D | Instance 0                       0
# Glycated haemoglobin (HbA1c) | Instance 0    0
# Alanine aminotransferase | Instance 0        0
# Alkaline phosphatase | Instance 0            0
# Apolipoprotein A | Instance 0                0
# Apolipoprotein B | Instance 0                0
# Aspartate aminotransferase | Instance 0      0
# Calcium | Instance 0                         0
# Direct bilirubin | Instance 0                0
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Participant ID                               0
# Haemoglobin concentration | Instance 0       0
# Albumin | Instance 0                         0
# Creatinine | Instance 0                      0
# C-reactive protein | Instance 0              0
# Cholesterol | Instance 0                     0
# HDL cholesterol | Instance 0                 0
# LDL direct | Instance 0                      0
# Glucose | Instance 0                         0
# Triglycerides | Instance 0                   0
# Vitamin D | Instance 0                       0
# Glycated haemoglobin (HbA1c) | Instance 0    0
# Alanine aminotransferase | Instance 0        0
# Alkaline phosphatase | Instance 0            0
# Apolipoprotein A | Instance 0                0
# Apolipoprotein B | Instance 0                0
# Aspartate aminotransferase | Instance 0      0
# Calcium | Instance 0                         0
# Direct bilirubin | Instance 0                0
# ...

# %%
del df
df = df2.copy()

# %%
df = df[['Participant ID',
 'Haemoglobin concentration | Instance 0',
 'Albumin | Instance 0',
 'Creatinine | Instance 0',
 'C-reactive protein | Instance 0',
 'Cholesterol | Instance 0',
 'HDL cholesterol | Instance 0',
 'LDL direct | Instance 0',
 'Glucose | Instance 0',
 'Triglycerides | Instance 0',
 'Vitamin D | Instance 0',
 'Glycated haemoglobin (HbA1c) | Instance 0',
 'Alanine aminotransferase | Instance 0',
 'Alkaline phosphatase | Instance 0',
 'Apolipoprotein A | Instance 0',
 'Apolipoprotein B | Instance 0',
 'Aspartate aminotransferase | Instance 0',
 'Calcium | Instance 0',
 'Direct bilirubin | Instance 0',
 'Gamma glutamyltransferase | Instance 0',
 'IGF-1 | Instance 0',
 'Lipoprotein A | Instance 0',
 'Phosphate | Instance 0',
 'trigl_hdl_ratio',
 'first_occurence_binary',
 'first_occurence_tertiary']]

# %%
df2 = df.copy()

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Participant ID                               0
# Haemoglobin concentration | Instance 0       0
# Albumin | Instance 0                         0
# Creatinine | Instance 0                      0
# C-reactive protein | Instance 0              0
# Cholesterol | Instance 0                     0
# HDL cholesterol | Instance 0                 0
# LDL direct | Instance 0                      0
# Glucose | Instance 0                         0
# Triglycerides | Instance 0                   0
# Vitamin D | Instance 0                       0
# Glycated haemoglobin (HbA1c) | Instance 0    0
# Alanine aminotransferase | Instance 0        0
# Alkaline phosphatase | Instance 0            0
# Apolipoprotein A | Instance 0                0
# Apolipoprotein B | Instance 0                0
# Aspartate aminotransferase | Instance 0      0
# Calcium | Instance 0                         0
# Direct bilirubin | Instance 0                0
# ...

# %%
del df
df = df2.copy()
def impute_median_labelbased(df, datacolumns, datalabel):
    df[datacolumns] = df[datacolumns].fillna(df.groupby(datalabel)[datacolumns].transform('median'))
    return df

# %%
df = dp.pre_blood_biomarker().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
df = impute_median_labelbased(df, df.columns.tolist()[1:-2], "first_occurence_binary")

# %%
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                               0
# Haemoglobin concentration | Instance 0       0
# Albumin | Instance 0                         0
# Creatinine | Instance 0                      0
# C-reactive protein | Instance 0              0
# Cholesterol | Instance 0                     0
# HDL cholesterol | Instance 0                 0
# LDL direct | Instance 0                      0
# Glucose | Instance 0                         0
# Triglycerides | Instance 0                   0
# Vitamin D | Instance 0                       0
# Glycated haemoglobin (HbA1c) | Instance 0    0
# Alanine aminotransferase | Instance 0        0
# Alkaline phosphatase | Instance 0            0
# Apolipoprotein A | Instance 0                0
# Apolipoprotein B | Instance 0                0
# Aspartate aminotransferase | Instance 0      0
# Calcium | Instance 0                         0
# Direct bilirubin | Instance 0                0
# ...

# %% [markdown]
# ### Blood-pressure

# %%
df = dp.pre_blood_pressure().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                 0
# Diastolic blood pressure    6170
# Systolic blood pressure     6172
# first_occurence_binary         0
# first_occurence_tertiary       0
# dtype: int64
# Dataframe dimensions:  (96678, 5)
# F1_macro:  0.5640767965329775 0.5536134440456092 0.533232298835094
# F1_micro:  0.5649993034854934 0.5536316512454503 0.533368536203615
# auc:  [0.5001344669935249, 0.588566705976888, 0.5744428987373437, 0.5484061799407255]
# accuracy:  [0.5001344669935249, 0.5649993034854934, 0.5536316512454503, 0.533368536203615]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Participant ID              0
# Diastolic blood pressure    0
# Systolic blood pressure     0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 5)
# F1_macro:  0.560834879351411 0.5501359498844454 0.5294754490122222
# F1_micro:  0.560923675255226 0.5503840544482256 0.5302771025765678
# auc:  [0.5, 0.5855420874545554, 0.5718904815103059, 0.546189825273814]
# accuracy:  [0.5, 0.560923675255226, 0.5503840544482256, 0.5302771025765678]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Participant ID              0
# Diastolic blood pressure    0
# Systolic blood pressure     0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 5)
# F1_macro:  0.5589736882348683 0.5500283004343479 0.5303095125971317
# F1_micro:  0.561283422459893 0.5506271268838113 0.5311521633446767
# auc:  [0.5, 0.5858700955675263, 0.5720845490303218, 0.5466367750987947]
# accuracy:  [0.5, 0.561283422459893, 0.5506271268838113, 0.5311521633446767]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Participant ID              0
# Diastolic blood pressure    0
# Systolic blood pressure     0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 5)
# F1_macro:  0.5903049246295128 0.580215611051716 0.5609260401665165
# F1_micro:  0.5911035488575596 0.5802430724355858 0.5610403500243072
# auc:  [0.5, 0.5938196452158688, 0.5791431702554021, 0.6007006782158176]
# accuracy:  [0.5, 0.5911035488575596, 0.5802430724355858, 0.5610403500243072]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                 0
# Diastolic blood pressure    6170
# Systolic blood pressure     6172
# first_occurence_binary         0
# first_occurence_tertiary       0
# dtype: int64
# Dataframe dimensions:  (96678, 5)
# F1_macro:  0.28446999441411297 0.28387440224761196 0.3559904546486325
# F1_micro:  0.5028651937364195 0.48960466649740614 0.4594426723089691
# auc:  [0.4998655330064751, 0.5936855586081731, 0.5884156981873431, 0.5420653655788861]
# accuracy:  [0.4998655330064751, 0.5028651937364195, 0.48960466649740614, 0.4594426723089691]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Participant ID              0
# Diastolic blood pressure    0
# Systolic blood pressure     0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 5)
# F1_macro:  0.2791745271536675 0.28171651630957456 0.35193427017210865
# F1_micro:  0.501507049100632 0.49010209042294606 0.46271268838113755
# auc:  [0.5, 0.5904493108117482, 0.5850279924181445, 0.5401937828371806]
# accuracy:  [0.5, 0.501507049100632, 0.49010209042294606, 0.46271268838113755]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Participant ID              0
# Diastolic blood pressure    0
# Systolic blood pressure     0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 5)
# F1_macro:  0.28044813840485144 0.28189878388361506 0.3504804789174529
# F1_micro:  0.5022070977151192 0.490034030140982 0.4613514827418571
# auc:  [0.5, 0.5903950061222534, 0.5851016437082847, 0.540292244182761]
# accuracy:  [0.5, 0.5022070977151192, 0.490034030140982, 0.4613514827418571]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Participant ID              0
# Diastolic blood pressure    0
# Systolic blood pressure     0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102850, 5)
# F1_macro:  0.28860453318933116 0.2856267520725376 0.40017272139281457
# F1_micro:  0.5017695673310647 0.48914924647544966 0.49169664560038895
# auc:  [0.5, 0.599278528110748, 0.5932869674211799, 0.5942662171112227]
# accuracy:  [0.5, 0.5017695673310647, 0.48914924647544966, 0.4916966456003889]

# %% [markdown]
# ### Demographics (basic)

# %%
df = dp.pre_demographics_basic().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID              0
# Age at recruitment          1
# Sex_binary                  0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102849, 5)
# F1_macro:  0.602337534299375 0.6016551395106204 0.602843672387743
# F1_micro:  0.6024171154192631 0.6020573625422363 0.6028546458033176
# auc:  [0.5000048614959796, 0.6366773009236039, 0.6365662023042106, 0.6364046579276179]
# accuracy:  [0.5000048614959796, 0.6024171154192631, 0.6020573625422363, 0.6028546458033176]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID              0
# Age at recruitment          1
# Sex_binary                  0
# first_occurence_binary      0
# first_occurence_tertiary    0
# dtype: int64
# Dataframe dimensions:  (102849, 5)
# F1_macro:  0.31948390372892094 0.33464168460101285 0.3108378905736007
# F1_micro:  0.5077443466484969 0.50635395199099 0.5084638524025504
# auc:  [0.49999513850402044, 0.6058611091971331, 0.6058510785218247, 0.6054137987382386]
# accuracy:  [0.49999513850402044, 0.5077443466484969, 0.50635395199099, 0.5084638524025504]

# %% [markdown]
# ### Urine biomarkers

# %%
df = dp.pre_urine_biomarkers().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                                      0
# Creatinine (enzymatic) in urine | Instance 0     4237
# Microalbumin in urine | Instance 0              63291
# Sodium in urine | Instance 0                     4436
# Potassium in urine | Instance 0                  4430
# albumin_creatine_ratio                          63292
# first_occurence_binary                              0
# first_occurence_tertiary                            0
# dtype: int64
# Dataframe dimensions:  (39353, 8)
# F1_macro:  0.4118597594692486 0.34126303627972304 0.5398620008698752
# F1_micro:  0.6309811465923596 0.4072116499907902 0.6108301475653231
# auc:  [0.6294564582115721, 0.5942714126727524, 0.5792041134053787, 0.5922243625029158]
# accuracy:  [0.6294564582115721, 0.6309811465923596, 0.4072116499907902, 0.6108301475653231]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Participant ID                                  0
# Creatinine (enzymatic) in urine | Instance 0    0
# Microalbumin in urine | Instance 0              0
# Sodium in urine | Instance 0                    0
# Potassium in urine | Instance 0                 0
# albumin_creatine_ratio                          0
# first_occurence_binary                          0
# first_occurence_tertiary                        0
# dtype: int64
# Dataframe dimensions:  (102850, 8)
# F1_macro:  0.5709178509197632 0.3781549052582013 0.5828021211953779
# F1_micro:  0.5719980554205153 0.5166747690811863 0.5828099173553719
# auc:  [0.5, 0.6013699434847725, 0.6026508532114276, 0.6152125020295426]
# accuracy:  [0.5, 0.5719980554205153, 0.5166747690811863, 0.5828099173553719]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Participant ID                                  0
# Creatinine (enzymatic) in urine | Instance 0    0
# Microalbumin in urine | Instance 0              0
# Sodium in urine | Instance 0                    0
# Potassium in urine | Instance 0                 0
# albumin_creatine_ratio                          0
# first_occurence_binary                          0
# first_occurence_tertiary                        0
# dtype: int64
# Dataframe dimensions:  (102850, 8)
# F1_macro:  0.5702734883398104 0.38482507932703286 0.5821419232625828
# F1_micro:  0.5743412736995624 0.5195333009236752 0.5821584832280019
# auc:  [0.5, 0.6156345523508543, 0.6030575681081402, 0.6147398283580097]
# accuracy:  [0.5, 0.5743412736995624, 0.5195333009236752, 0.5821584832280019]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Participant ID                                  0
# Creatinine (enzymatic) in urine | Instance 0    0
# Microalbumin in urine | Instance 0              0
# Sodium in urine | Instance 0                    0
# Potassium in urine | Instance 0                 0
# albumin_creatine_ratio                          0
# first_occurence_binary                          0
# first_occurence_tertiary                        0
# dtype: int64
# Dataframe dimensions:  (102850, 8)
# F1_macro:  0.7677937066174672 0.3821633201754003 0.8495341232501823
# F1_micro:  0.7692950899368012 0.5184735051045212 0.8499173553719008
# auc:  [0.5, 0.7850383279263404, 0.7277791281014188, 0.9439522438882704]
# accuracy:  [0.5, 0.7692950899368012, 0.5184735051045212, 0.8499173553719008]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                                      0
# Creatinine (enzymatic) in urine | Instance 0     4237
# Microalbumin in urine | Instance 0              63291
# Sodium in urine | Instance 0                     4436
# Potassium in urine | Instance 0                  4430
# albumin_creatine_ratio                          63292
# first_occurence_binary                              0
# first_occurence_tertiary                            0
# dtype: int64
# Dataframe dimensions:  (39353, 8)
# F1_macro:  0.36736142964361224 0.23327804434162597 0.3862202144406015
# F1_micro:  0.4133867540391223 0.3890173585276045 0.4050008741658093
# auc:  [0.3705435417884278, 0.5835955592936284, 0.5745906544994446, 0.5712718798263059]
# accuracy:  [0.3705435417884278, 0.4133867540391223, 0.3890173585276045, 0.4050008741658093]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Participant ID                                  0
# Creatinine (enzymatic) in urine | Instance 0    0
# Microalbumin in urine | Instance 0              0
# Sodium in urine | Instance 0                    0
# Potassium in urine | Instance 0                 0
# albumin_creatine_ratio                          0
# first_occurence_binary                          0
# first_occurence_tertiary                        0
# dtype: int64
# Dataframe dimensions:  (102850, 8)
# F1_macro:  0.269600728617632 0.2655314349743546 0.38235522582016424
# F1_micro:  0.5016334467671366 0.5074574623237724 0.4898006806028196
# auc:  [0.5, 0.5799608034025227, 0.5814542181717332, 0.5863784170602658]
# accuracy:  [0.5, 0.5016334467671366, 0.5074574623237724, 0.4898006806028196]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Participant ID                                  0
# Creatinine (enzymatic) in urine | Instance 0    0
# Microalbumin in urine | Instance 0              0
# Sodium in urine | Instance 0                    0
# Potassium in urine | Instance 0                 0
# albumin_creatine_ratio                          0
# first_occurence_binary                          0
# first_occurence_tertiary                        0
# dtype: int64
# Dataframe dimensions:  (102850, 8)
# F1_macro:  0.2831830540652835 0.26763547186315195 0.38189118634305425
# F1_micro:  0.507175498298493 0.5085755955274672 0.48905201750121535
# auc:  [0.5, 0.5939350060344073, 0.5815460869300029, 0.5859510913799257]
# accuracy:  [0.5, 0.507175498298493, 0.5085755955274672, 0.48905201750121535]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Participant ID                                  0
# Creatinine (enzymatic) in urine | Instance 0    0
# Microalbumin in urine | Instance 0              0
# Sodium in urine | Instance 0                    0
# Potassium in urine | Instance 0                 0
# albumin_creatine_ratio                          0
# first_occurence_binary                          0
# first_occurence_tertiary                        0
# dtype: int64
# Dataframe dimensions:  (102850, 8)
# F1_macro:  0.5491436661699527 0.266735501502549 0.7459763178719494
# F1_micro:  0.6547496353913467 0.5082547399124939 0.7715605250364609
# auc:  [0.5, 0.7123654367136987, 0.6903617992212303, 0.9316953267827995]
# accuracy:  [0.5, 0.6547496353913467, 0.5082547399124939, 0.7715605250364609]

# %% [markdown]
# ### Medications (cholesterol, insulin, blood-pressure)

# %%
df = dp.pre_medications().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                     0
# Cholesterol_lowering_medication    0
# Insulin                            0
# Blood_pressure                     0
# first_occurence_binary             0
# first_occurence_tertiary           0
# dtype: int64
# Dataframe dimensions:  (102850, 6)
# F1_macro:  0.7252749853278255 0.6508330138527576 0.7252749853278255
# F1_micro:  0.7257462323772484 0.6728342245989305 0.7257462323772484
# auc:  [0.5, 0.7555896199916384, 0.7555752327504243, 0.7555909737290337]
# accuracy:  [0.5, 0.7257462323772484, 0.6728342245989305, 0.7257462323772484]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                     0
# Cholesterol_lowering_medication    0
# Insulin                            0
# Blood_pressure                     0
# first_occurence_binary             0
# first_occurence_tertiary           0
# dtype: int64
# Dataframe dimensions:  (102850, 6)
# F1_macro:  0.47278478856541956 0.4509520704747203 0.47278478856541956
# F1_micro:  0.6335051045211473 0.5633641225085075 0.6335051045211473
# auc:  [0.5, 0.7265605272543819, 0.7200871690149273, 0.7265572409468403]
# accuracy:  [0.5, 0.6335051045211473, 0.5633641225085075, 0.6335051045211473]

# %% [markdown]
# ### Alcohol

# %%
df = dp.pre_alcohol().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                                                       0
# Alcohol intake frequency. | Instance 0_Daily or almost daily         0
# Alcohol intake frequency. | Instance 0_Never                         0
# Alcohol intake frequency. | Instance 0_Once or twice a week          0
# Alcohol intake frequency. | Instance 0_One to three times a month    0
# Alcohol intake frequency. | Instance 0_Special occasions only        0
# Alcohol intake frequency. | Instance 0_Three or four times a week    0
# first_occurence_binary                                               0
# first_occurence_tertiary                                             0
# dtype: int64
# Dataframe dimensions:  (102850, 9)
# F1_macro:  0.572745439203329 0.5707429573032701 0.572745439203329
# F1_micro:  0.5795527467185221 0.5780554205153136 0.5795527467185221
# auc:  [0.5, 0.6015962738189126, 0.6011983809036056, 0.6015962738189126]
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                                                       0
# Alcohol intake frequency. | Instance 0_Daily or almost daily         0
# Alcohol intake frequency. | Instance 0_Never                         0
# Alcohol intake frequency. | Instance 0_Once or twice a week          0
# Alcohol intake frequency. | Instance 0_One to three times a month    0
# Alcohol intake frequency. | Instance 0_Special occasions only        0
# Alcohol intake frequency. | Instance 0_Three or four times a week    0
# first_occurence_binary                                               0
# first_occurence_tertiary                                             0
# dtype: int64
# Dataframe dimensions:  (102850, 9)
# F1_macro:  0.2993808207935506 0.33494361813222817 0.3000399114951604
# F1_micro:  0.5049586776859504 0.4975401069518717 0.5049392318911036
# auc:  [0.5, 0.5786798112676491, 0.5781318253209738, 0.5786816635182099]
# ...

# %% [markdown]
# ### Family history (other)

# %%
df = dp.pre_family_history_other().merge(labels, on="Participant ID")
df2 = df.copy()
# Out:
# C:\Users\keimp\NHS\Code\experimental_modeling\diabetes\experimental_modeling_pipeline.py:860: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   return pd.np.nan

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                  0
# father_stroke                   0
# mother_stroke                   0
# sibling_stroke                  0
# father_alzheimer             3748
# mother_alzheimer             2591
# sibling_alzheimer           14777
# father_bloodpressure            0
# mother_bloodpressure            0
# sibling_bloodpressure           0
# father_heart                    0
# mother_heart                    0
# sibling_heart                   0
# father_parkinson                0
# mother_parkinson                0
# sibling_parkinson               0
# first_occurence_binary          0
# first_occurence_tertiary        0
# dtype: int64
# Dataframe dimensions:  (86974, 18)
# F1_macro:  0.5394267099400349 0.493427393476042 0.5398112741652025
# F1_micro:  0.5529353707289484 0.5410582471818046 0.5489226401296129
# auc:  [0.5053579230574654, 0.5666345803250409, 0.5605300483947547, 0.5593687019453217]
# ...

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                  0
# father_stroke                   0
# mother_stroke                   0
# sibling_stroke                  0
# father_alzheimer             3748
# mother_alzheimer             2591
# sibling_alzheimer           14777
# father_bloodpressure            0
# mother_bloodpressure            0
# sibling_bloodpressure           0
# father_heart                    0
# mother_heart                    0
# sibling_heart                   0
# father_parkinson                0
# mother_parkinson                0
# sibling_parkinson               0
# first_occurence_binary          0
# first_occurence_tertiary        0
# dtype: int64
# Dataframe dimensions:  (86974, 18)
# F1_macro:  0.24288397815360346 0.2974896974880181 0.2636530742483407
# F1_micro:  0.5051509622792025 0.49463059405728876 0.5015866899354371
# auc:  [0.5053579230574654, 0.5519915215166932, 0.5458066769461738, 0.5408046992748785]
# ...

# %% [markdown]
# ### Physical activity

# %%
df = dp.pre_physical_activity().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Summed MET minutes per week for all activity | Instance 0    22140
# Summed minutes activity | Instance 0                         22140
# Participant ID                                                   0
# first_occurence_binary                                           0
# first_occurence_tertiary                                         0
# dtype: int64
# Dataframe dimensions:  (80710, 5)
# F1_macro:  0.3401463434574664 0.5452550253406481 0.513164642469035
# F1_micro:  0.5154875480113988 0.5572667575269483 0.5136786024036675
# auc:  [0.5154875480113988, 0.5046530407004668, 0.561136052512302, 0.5238310904972501]
# accuracy:  [0.5154875480113988, 0.5154875480113988, 0.5572667575269483, 0.5136786024036675]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Summed MET minutes per week for all activity | Instance 0    22140
# Summed minutes activity | Instance 0                             0
# Participant ID                                                   0
# first_occurence_binary                                           0
# first_occurence_tertiary                                         0
# dtype: int64
# Dataframe dimensions:  (80710, 5)
# F1_macro:  0.3401463434574664 0.5452550253406481 0.5130361823084114
# F1_micro:  0.5154875480113988 0.5572667575269483 0.5135423119811672
# auc:  [0.5154875480113988, 0.5046530407004668, 0.561136052512302, 0.5238516625626257]
# accuracy:  [0.5154875480113988, 0.5154875480113988, 0.5572667575269483, 0.5135423119811672]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Summed MET minutes per week for all activity | Instance 0    22140
# Summed minutes activity | Instance 0                             0
# Participant ID                                                   0
# first_occurence_binary                                           0
# first_occurence_tertiary                                         0
# dtype: int64
# Dataframe dimensions:  (80710, 5)
# F1_macro:  0.3401463434574664 0.5452550253406481 0.5129067756049166
# F1_micro:  0.5154875480113988 0.5572667575269483 0.5134184115970759
# auc:  [0.5154875480113988, 0.5046530407004668, 0.561136052512302, 0.5244203876666503]
# accuracy:  [0.5154875480113988, 0.5154875480113988, 0.5572667575269483, 0.5134184115970759]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Summed MET minutes per week for all activity | Instance 0    22140
# Summed minutes activity | Instance 0                             0
# Participant ID                                                   0
# first_occurence_binary                                           0
# first_occurence_tertiary                                         0
# dtype: int64
# Dataframe dimensions:  (80710, 5)
# F1_macro:  0.3401463434574664 0.5452550253406481 0.5128224139211929
# F1_micro:  0.5154875480113988 0.5572667575269483 0.513331681328212
# auc:  [0.5154875480113988, 0.5046530407004668, 0.561136052512302, 0.5241038808783375]
# accuracy:  [0.5154875480113988, 0.5154875480113988, 0.5572667575269483, 0.513331681328212]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Summed MET minutes per week for all activity | Instance 0    22140
# Summed minutes activity | Instance 0                         22140
# Participant ID                                                   0
# first_occurence_binary                                           0
# first_occurence_tertiary                                         0
# dtype: int64
# Dataframe dimensions:  (80710, 5)
# F1_macro:  0.22676422897164428 0.22676422897164428 0.3441738025934694
# F1_micro:  0.5154875480113988 0.5154875480113988 0.3957997769793086
# auc:  [0.5154875480113988, 0.5036757635117578, 0.5501573918822658, 0.515784913787571]
# accuracy:  [0.5154875480113988, 0.5154875480113988, 0.5154875480113988, 0.3957997769793086]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean")
# Out:
# Number of missing values:
#  Summed MET minutes per week for all activity | Instance 0    22140
# Summed minutes activity | Instance 0                             0
# Participant ID                                                   0
# first_occurence_binary                                           0
# first_occurence_tertiary                                         0
# dtype: int64
# Dataframe dimensions:  (80710, 5)
# F1_macro:  0.22676422897164428 0.22676422897164428 0.3443495269060748
# F1_micro:  0.5154875480113988 0.5154875480113988 0.3960723578243093
# auc:  [0.5154875480113988, 0.5036757635117578, 0.5501573918822658, 0.515922015094312]
# accuracy:  [0.5154875480113988, 0.5154875480113988, 0.5154875480113988, 0.3960723578243093]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="median")
# Out:
# Number of missing values:
#  Summed MET minutes per week for all activity | Instance 0    22140
# Summed minutes activity | Instance 0                             0
# Participant ID                                                   0
# first_occurence_binary                                           0
# first_occurence_tertiary                                         0
# dtype: int64
# Dataframe dimensions:  (80710, 5)
# F1_macro:  0.22676422897164428 0.22676422897164428 0.3445084912864742
# F1_micro:  0.5154875480113988 0.5154875480113988 0.39603518770908186
# auc:  [0.5154875480113988, 0.5036757635117578, 0.5501573918822658, 0.5163844844924]
# accuracy:  [0.5154875480113988, 0.5154875480113988, 0.5154875480113988, 0.3960351877090819]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5, impute="mean_labelbased")
# Out:
# Number of missing values:
#  Summed MET minutes per week for all activity | Instance 0    22140
# Summed minutes activity | Instance 0                             0
# Participant ID                                                   0
# first_occurence_binary                                           0
# first_occurence_tertiary                                         0
# dtype: int64
# Dataframe dimensions:  (80710, 5)
# F1_macro:  0.22676422897164428 0.22676422897164428 0.3443954827135634
# F1_micro:  0.5154875480113988 0.5154875480113988 0.3959856275554454
# auc:  [0.5154875480113988, 0.5036757635117578, 0.5501573918822658, 0.5160461581952417]
# accuracy:  [0.5154875480113988, 0.5154875480113988, 0.5154875480113988, 0.3959856275554454]

# %% [markdown]
# ### Sleep

# %%
df = dp.pre_sleep().merge(labels, on="Participant ID")
df2 = df.copy()
# Out:
# C:\Users\keimp\NHS\Code\experimental_modeling\diabetes\experimental_modeling_pipeline.py:697: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   sleep = sleep.replace("Prefer not to answer", pd.np.nan)
# C:\Users\keimp\NHS\Code\experimental_modeling\diabetes\experimental_modeling_pipeline.py:698: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   sleep = sleep.replace("Do not know", pd.np.nan)

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                    0
# Sleep duration | Instance 0    1231
# first_occurence_binary            0
# first_occurence_tertiary          0
# dtype: int64
# Dataframe dimensions:  (101619, 4)
# F1_macro:  0.4006947861578568 0.48157846122265785 0.5401740288760333
# F1_micro:  0.5182692485266702 0.5410503341900188 0.5491984638987651
# auc:  [0.5025044529074287, 0.49806797628429234, 0.5634901068752302, 0.5634750094356801]
# accuracy:  [0.5025044529074287, 0.5182692485266702, 0.5410503341900188, 0.5491984638987651]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                    0
# Sleep duration | Instance 0    1231
# first_occurence_binary            0
# first_occurence_tertiary          0
# dtype: int64
# Dataframe dimensions:  (101619, 4)
# F1_macro:  0.2229903104879625 0.261676322439306 0.26335293861256787
# F1_micro:  0.5025142932972777 0.5058404348980652 0.5059585228572334
# auc:  [0.5025044529074287, 0.5112405784666427, 0.5491754733441325, 0.5499150214701048]
# accuracy:  [0.5025044529074287, 0.5025142932972777, 0.5058404348980652, 0.5059585228572334]

# %% [markdown]
# ### Smoking

# %%
df = dp.pre_smoking().merge(labels, on="Participant ID")
df2 = df.copy()

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_binary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                                0
# Tobacco smoking_Ex-smoker                     0
# Tobacco smoking_Never smoked                  0
# Tobacco smoking_Occasionally                  0
# Tobacco smoking_Smokes on most or all days    0
# first_occurence_binary                        0
# first_occurence_tertiary                      0
# dtype: int64
# Dataframe dimensions:  (102850, 7)
# F1_macro:  0.5014506611107002 0.5014506611107002 0.5014506611107002
# F1_micro:  0.5450461837627613 0.5450461837627613 0.5450461837627613
# auc:  [0.5, 0.5474863493025346, 0.5470476533052061, 0.5474811290945061]
# accuracy:  [0.5, 0.5450461837627613, 0.5450461837627613, 0.5450461837627613]

# %%
del df
df = df2.copy()
emp.pipeline(df, "first_occurence_tertiary", df.columns[1:-2].tolist(), 0.25, multiclass=1, splits=5)
# Out:
# Number of missing values:
#  Participant ID                                0
# Tobacco smoking_Ex-smoker                     0
# Tobacco smoking_Never smoked                  0
# Tobacco smoking_Occasionally                  0
# Tobacco smoking_Smokes on most or all days    0
# first_occurence_binary                        0
# first_occurence_tertiary                      0
# dtype: int64
# Dataframe dimensions:  (102850, 7)
# F1_macro:  0.2222222222222222 0.2557667979340148 0.2222222222222222
# F1_micro:  0.5 0.34035002430724354 0.5
# auc:  [0.5, 0.5368278974251482, 0.536415605233598, 0.5368277739532211]
# accuracy:  [0.5, 0.5, 0.34035002430724354, 0.5]
